# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/flood_risk_dataset_india.csv")

# %%
df.head(10)
# Out:
#     Latitude  Longitude  Rainfall (mm)  Temperature (°C)  Humidity (%)  \
# 0  18.861663  78.835584     218.999493         34.144337     43.912963
# 1  35.570715  77.654451      55.353599         28.778774     27.585422
# 2  29.227824  73.108463     103.991908         43.934956     30.108738
# 3  25.361096  85.610733     198.984191         21.569354     34.453690
# 4  12.524541  81.822101     144.626803         32.635692     36.292267
# 5  12.523841  93.105329     221.571312         36.006300     39.380945
# 6   9.684425  68.931178     288.362370         39.766935     40.436802
# 7  33.119108  86.672170      34.964006         27.209131     56.457308
# 8  25.432335  90.125517     212.870315         35.607657     60.765855
# 9  28.534105  90.025111      69.103247         24.096044     44.710337
#
#    River Discharge (m³/s)  Water Level (m)  Elevation (m)    Land Cover  \
# 0             4236.182888         7.415552     377.465433    Water Body
# ...

# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
df = pd.read_csv("flood_risk_dataset_india.csv")

# Separate features and target
X = df.drop('Flood Occurred', axis=1)
y = df['Flood Occurred']

# One-hot encode categorical variables (if any)
X_encoded = pd.get_dummies(X, drop_first=True)

# Save the feature names for later use in prediction
feature_columns = X_encoded.columns.tolist()

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Train the RandomForest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred))

# Save model and feature columns for future use (e.g., in Streamlit app)
joblib.dump(model, "random_forest_model.pkl")
joblib.dump(feature_columns, "model_features.pkl")  # This ensures input features during prediction match training
# Out:
# Model Accuracy: 0.51
#               precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50       966
#            1       0.53      0.51      0.52      1034
#
#     accuracy                           0.51      2000
#    macro avg       0.51      0.51      0.51      2000
# weighted avg       0.51      0.51      0.51      2000
# ['model_features.pkl']
